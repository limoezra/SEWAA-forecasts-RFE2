# %%
# Explore the CRPS of different runs

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Current candidate for Mvua Kubwa 2 is run 9

# Run filters_gen filters_disc batch_size IMERG cape climate
# 9   64          256          4          7     no   no

# 2020
# Run N      CRPS     CRPS_max_4 CRPS_max_16 CRPS_avg_4 CRPS_avg_16 RMSE     EMRMSE   RALSD    MAE      OPL      OPR
# mk2 300800 0.062358 0.110245   0.244286    0.058929   0.050333    0.324696 0.264018 1.940648 0.109075 0.047486 0.041314
# 9   172544 0.061507 0.108869   0.241619    0.058041   0.049442    0.317083 0.262418 2.391198 0.103092 0.041476 0.035003

# 2021
# Run N      CRPS     CRPS_max_4 CRPS_max_16 CRPS_avg_4 CRPS_avg_16 RMSE     EMRMSE   RALSD    MAE      OPL      OPR
# mk1 160000 0.050451 0.090546   0.201136    0.047551   0.040228    0.279500 0.221887 2.056868 0.087265 0.033566 0.045484
# mk2 300800 0.050333 0.089959   0.197547    0.047362   0.039791    0.278986 0.220980 1.932968 0.089129 0.040566 0.046101
# mk3 320000 0.051114 0.091362   0.201618    0.048271   0.041199    0.260668 0.223634 2.812439 0.080244 0.052119 0.040838
# 9   172544 0.050154 0.089619   0.196132    0.047215   0.039874    0.269518 0.221368 2.496339 0.083377 0.036182 0.035965

# %%
# Run 1
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run1/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3,  nrows=14)
plt.plot(df["N"],df["CRPS"],'o-',label=f"Run 1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 1b
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run1/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=21,  nrows=50)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 1c
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run1/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=75,  nrows=50)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 1d
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run1/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=129, nrows=100)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 1e
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run1/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=233, nrows=200)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 2
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run2/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 2: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 3
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run3/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 3: min CRPS = {np.min(df["CRPS"])}, batch_size = 4")

#plt.xlim(0,1000)
plt.ylim(0.06,0.15)

plt.grid()
plt.xlabel("N")
plt.ylabel("CRPS")
plt.title("filters_gen = 16, filters_disc = 64")
plt.legend()
plt.show()

# %%
# Mk1
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_bak/logs/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"]/5,df["CRPS"],'.-',label=f"mk1: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Mk2
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h/logs/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"]/5,df["CRPS"],'.-',label=f"mk2: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Mk3
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk3/logs/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"]/5,df["CRPS"],'.--',label=f"mk3: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# # Run 4
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run4/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=3)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 4: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# # Run 5
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run5/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=3, nrows=50)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 5: min CRPS = {np.min(df["CRPS"])}, batch_size = 4")

# # Run 5b
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run5/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=57)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 5: min CRPS = {np.min(df["CRPS"])}, batch_size = 4")

# # Run 6
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run6/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=3, nrows=25)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 6: min CRPS = {np.min(df["CRPS"])}, batch_size = 8")

# # Run 6b
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run6/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=32, nrows=25)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 6: min CRPS = {np.min(df["CRPS"])}, batch_size = 8")

# # Run 6c
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run6/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=61)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 6: min CRPS = {np.min(df["CRPS"])}, batch_size = 8")

# # Run 7
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run7/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=3, nrows=25)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 7: min CRPS = {np.min(df["CRPS"])}, batch_size = 16")

# # Run 7b
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run7/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=32, nrows=25)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 7: min CRPS = {np.min(df["CRPS"])}, batch_size = 16")

# # Run 7c
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run7/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=61, nrows=50)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 7: min CRPS = {np.min(df["CRPS"])}, batch_size = 16")

# # Run 7d
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run7/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=115)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 7: min CRPS = {np.min(df["CRPS"])}, batch_size = 16")

# Run 8
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run8/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 8: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

plt.ylim(0.065,0.09)

plt.grid()
plt.xlabel("N")
plt.ylabel("CRPS")
plt.title("filters_gen = 32, filters_disc = 128")
plt.legend()
plt.show()

# %%
# Mk3
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk3/logs/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=3)
plt.plot(df["N"],df["CRPS"],'.-',label=f"mk3: min CRPS = {np.min(df["CRPS"])}, batch_size = 2")

# Run 9
# file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run9/eval_validation.txt"
# df = pd.read_table(file_name, sep=' ', header=3, nrows=200)
# plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 9: min CRPS = {np.min(df["CRPS"])}, batch_size = 4")

# Run 9b
file_name = "/home/c/cooperf/data/cGAN/ICPAC/24h_IMERG_v7_30h-54h_mk4/logs_run9/eval_validation.txt"
df = pd.read_table(file_name, sep=' ', header=207)
plt.plot(df["N"],df["CRPS"],'.-',label=f"Run 9: min CRPS = {np.min(df["CRPS"])}, batch_size = 4")

plt.ylim(0.06,0.1)

plt.grid()
plt.xlabel("N")
plt.ylabel("CRPS")
plt.title("filters_gen = 64, filters_disc = 256")
plt.legend()
plt.show()

# %%
df.shape
# Out:
# (400, 12)

# %%
idx = np.argsort(df["CRPS"])
print(df["CRPS"][idx[:5]])
print(df["N"][idx[:5]])
# Out:
# 176    0.065343
# 186    0.065522
# 336    0.065559
# 211    0.065774
# 208    0.065819
# Name: CRPS, dtype: float64
# 176     90624
# 186     95744
# 336    172544
# 211    108544
# 208    107008
# Name: N, dtype: int64
